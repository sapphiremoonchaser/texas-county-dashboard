# %%
# Imports
import pandas as pd
import os
from dotenv import load_dotenv

from src.texas_county_dashboards.scripts.census_client import CensusClient
from src.texas_county_dashboards.analytics.county_analytics import CountyAnalytics

# %%
# Retrieve the api key
load_dotenv()
api_key = os.getenv("CENSUS_API_KEY")

census_client = CensusClient(
    api_key=api_key
)

# %%
county_profile = census_client.county_profile()

county_profile.head()
# Out:
#   state county  GEOID                    NAME  population
# 0    48    001  48001  Anderson County, Texas       58439
# 1    48    003  48003   Andrews County, Texas       18610
# 2    48    005  48005  Angelina County, Texas       87275
# 3    48    007  48007   Aransas County, Texas       24876
# 4    48    009  48009    Archer County, Texas        8867
